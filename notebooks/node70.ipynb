# %% [markdown]
# [Node 70: Aufgaben](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node70.html)

# %% [markdown]
# Navigation:
#
# **Up:** [Web-Programmierung und Django](node67.ipynb) **Previous:** [Web-Programmierung und Django](node67.ipynb)

# %% [markdown]
# ##  Tasks
#
# * Familiarize yourself with the [``basehttpcalc.py``](source/basehttpcalc.py) program and expand it with additional arithmetic commands.
# * Extend the <font color=#0000e6> ``CGIHTTPServer``</font> example by passing input parameters to the CGI script via the HTML address and outputting them on the web page.
#
# Solution: Create a directory cgitest, place the following file in it: [test_cgiserver.py](source/test_cgiserver.py), then create a subdirectory cgi-bin in the directory cgitest and place the following file in it: [test_cgiserver.py](source/test_cgiserver.py). This file must be executable. Start the CGIServer in the cgitest directory and point a web browser to: <font color=#0000e6> ``http://localhost:9090/cgi-bin/cgiprintenv.py?42``</font>
# * Generate an index page for the URL <font color=#0000e6> ``http://localhost:9090/wikicamp/``</font> , which displays an index of all available wiki pages in the database.
# Solution: [urls.py](source/solutions/django_wiki_urls.py), [urls.py](source/solutions/django_wiki_urls.py), [urls.py](source/solutions/django_wiki_urls.py)
