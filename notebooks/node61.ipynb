# %% [markdown]
# [Node 61: Pandas – Datenanalyse mit Python](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node61.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Netzwerk-Programmierung](node62.ipynb) **Up:** [Netzwerk-Programmierung](node62.ipynb) **Previous:** [Netzwerk-Programmierung](node62.ipynb)

# %% [markdown]
# # Pandas - Data analysis with Python
#
# * <font color=#0000ff> **Pandas**</font> ([html](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/nb/PandasIntro.html), [html](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/nb/PandasIntro.html))
# * <font color=#0000ff> **Exercises**</font> ([html](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/nb/PandasExercises.html), [html](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/nb/PandasExercises.html))
