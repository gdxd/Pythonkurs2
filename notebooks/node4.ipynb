# %% [markdown]
# [Node 4: Computing Kenntnisse für Physiker – eine Wunschliste](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node4.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Python-Features](node5.ipynb) **Up:** [Python-Features](node5.ipynb) **Previous:** [Python-Features](node5.ipynb)

# %% [markdown]
# # Computing skills for physicists - a wish list
#
# * <font color=#ff0000> **Everyday life:**</font> Word processing (Office, Latex), presentations (PPT, TeX), WWW use, email $\Rightarrow$ <font color=#008000> * Self study*</font>
# * <font color=#ff0000> **Data Analysis/Statistics:**</font> Spreadsheet (Excel), SAS, ROOT $\Rightarrow$ <font color=#008000> *(Self/Course)*</font>
# * <font color=#ff0000> **Math/Symbolic Algebra:**</font> Maple, Mathematica, ... $\Rightarrow$ <font color=#008000> *(Self/Course)*</font>
# * <font color=#ff0000> **High level language:**</font> Fortran, C/C++, Java, ...$\Rightarrow$ <font color=#008000> *Courses*</font>
# * <font color=#ff0000> **Numerics**</font> : Algorithms (Fortran/C++) $\Rightarrow$ <font color=#008000> *Lecture (Schein)*</font>
# * <font color=#ff0000> **Advanced concepts:**</font> OO programming and design, GUI, threads, containers $\Rightarrow$ <font color=#008000> *Courses*</font>
# * <font color=#ff0000> **Hardware Programming**</font> $\Rightarrow$ <font color=#008000> *(Course)*</font>
# * <font color=#ff0000> **High Level IT applications:**</font> Databases, XML, scripting languages, web programming, grid, ... $\Rightarrow$ <font color=#008000> * Python Courses*</font>
#
#
#
# ---
