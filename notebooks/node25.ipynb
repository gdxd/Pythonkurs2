# %% [markdown]
# [Node 25: Wozu UML ?](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node25.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Klassen in UML](node26.ipynb) **Up:** [Klassen in UML](node26.ipynb) **Previous:** [Klassen in UML](node26.ipynb)

# %% [markdown]
# ## Why UML ?
#
# “Default Language” to
# * Represent software systems <font color=#008000> *(different than in the source-code editor)*</font>
# * Express dependencies and relationships
# * Visualize processes
# * Develop requirements
# * Further abstraction
#
# Nothing new for physicists:
# * <font color=#ff0000> **Mathematics**</font> for the abstract, formal description of nature
# * Feynman diagrams for particle physics reactions.
