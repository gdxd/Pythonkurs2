# %% [markdown]
# [Node 67: Webprogrammierung und Django](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node67.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Web-Programmierung](node68.ipynb) **Up:** [Web-Programmierung](node68.ipynb) **Previous:** [Web-Programmierung](node68.ipynb)

# %% [markdown]
# # Web programming and Django
#
# In this section, let's first look at programming a simple HTTP server in Python. In the following notebook we will then write a simple wiki server using the Django web framework.
#
# ## Subchapters
# * [Web-Programmierung](node68.ipynb)
# * [Web-Framework Django](node69.ipynb)
# * [Aufgaben](node70.ipynb)
