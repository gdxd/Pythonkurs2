# %% [markdown]
# [Node 28: Objekt-Diagramme](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node28.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Sequenz-Diagramme](node29.ipynb) **Up:** [Sequenz-Diagramme](node29.ipynb) **Previous:** [Sequenz-Diagramme](node29.ipynb)

# %% [markdown]
# ## Object diagrams
#
# Class diagrams describe the <font color=#0000ff> **static design**</font> of the program structure:
# * fixed, no change in the program flow
#
# ![Image ParticleClass](figures/UML_ParticleClass.png "Image ParticleClass")
#
# Similarly <font color=#0000ff> **Object Diagrams**</font>:
# * Relationship between objects. Only valid for a specific point in time during the program runtime!
#
# ![Image ParticleObj](figures/UML_ParticleObj.png "Image ParticleObj")
