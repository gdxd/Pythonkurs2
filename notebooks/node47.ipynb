# %% [markdown]
# [Node 47: Aufgaben](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node47.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Object I/O (Serializing), Database](node48.ipynb) **Up:** [Object I/O (Serializing) **Previous:** [Object I/O (Serializing)

# %% [markdown]
# ##  Tasks
#
# * **Prime numbers**
#
# Apply profiling to the prime number calculation algorithm from the first Python course.
#
#
# Using the timer, `cProfile` and `line profiler`, find the lines in the program code that take the most time (See exercise 7 (b): [Python-Kurs](http://www.etp.physik.uni-muenchen.de/kurs/Computing/python/node26.html), [Python-Kurs](http://www.etp.physik.uni-muenchen.de/kurs/Computing/python/node26.html)).
