# %% [markdown]
# [Node 66: Aufgaben](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node66.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Webprogrammierung und Django](node67.ipynb) **Up:** [Webprogrammierung und Django](node67.ipynb) **Previous:** [Webprogrammierung und Django](node67.ipynb)

# %% [markdown]
# ##  Tasks
#
# * Extend the echo server from the [SockerServer-Abschnitt](node64.ipynb) so that it can be used as a calculator, i.e. inputs of e.g. '1+1' are answered with the correct result. In principle, the desired functionality can be achieved with just one additional command to the existing code - but this can lead to a significant security hole. Why? How should the pocket calculator be realized instead?
#
# Solution: [echo_calculator.py](source/solutions/echo_calculator.py)
#
#
# * Write a distributed program that calculates the number $\pi$ on multiple computers using the methods presented in the previous chapter. Does the chosen method make sense to increase the precision of the number $\pi$ ?
#
# Solution: [xmlrpc_pi_server.py](source/solutions/xmlrpc_pi_server.py), [xmlrpc_pi_server.py](source/solutions/xmlrpc_pi_server.py)
