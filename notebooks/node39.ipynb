# %% [markdown]
# [Node 39: Aufgaben](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node39.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Profiling von Programmen](node40.ipynb) **Up:** [Profiling von Programmen](node40.ipynb) **Previous:** [Profiling von Programmen](node40.ipynb)

# %% [markdown]
# ##  Tasks
#
# * **Prime numbers**
#
# Write a test for the prime number calculation algorithm from the first Python course (See Task 7(a): [Python-Kurs](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python/node26.html), [Python-Kurs](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python/node26.html))
