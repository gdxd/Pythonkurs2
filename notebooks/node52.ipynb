# %% [markdown]
# [Node 52: Aufgaben](http://www-static.etp.physik.uni-muenchen.de/kurs/Computing/python2/node52.html)

# %% [markdown]
# Navigation:
#
# **Next:** [Datenformate II – XML](node53.ipynb) **Up:** [Datenformate II – XML](node53.ipynb) **Previous:** [Datenformate II – XML](node53.ipynb)

# %% [markdown]
# ##  Tasks
#
# 1. You have the following data available:
# <pre>
# Max Mueller 123498765 1.3
# Lise Meier 123498764 2.0
# Heinz Schmitt 123498761 1.0
# Maria Kunz 123498762 3.0
# Karl Hinz 12349879 3.3
# Anna pattern 12349878 1.7
# </pre>
#
# Save this data to an ASCII file, define an appropriate data type, read the data from the ASCII file, and save this data in <font color=#0000e6> ``pickle``</font> format away. Then read this data back in from the <font color=#0000e6> ``pickle``</font> file and check the consistency of the data.
#
# Solution: [test_pickle.py](source/solutions/db_test_pickle.py)
#
#
# 1. Create a table in <font color=#0000e6> ``SQLite3``</font> with the previous data and read it with the <font color=#0000e6> ``cursor``</font> function out.
#
# Solution: [studenten.schema](data/db_studenten.schema)
#
# Solution: [test_sqlite3.py](source/solutions/db_test_sqlite3.py)
# 1. Do the SQlite/DB Tutorial on [ **Software Carpentry: Databases and SQL** ](http://swcarpentry.github.io/sql-novice-survey/index.html).
#
# Here is the SQlite file with the tables: [survey.sqlite](source/survey.sqlite)
